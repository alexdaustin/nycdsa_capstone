# %% [markdown]
# ## The purpose of this notebook is to output a processed dataset that covers the same time span as that generated from the 1-day data and check they are essentially the same.

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import re

# %%
sessions = pd.read_csv('sessions.csv', index_col=0)
sessions.rename(columns={'SessionID':'SessionId'})
sessions.head()
# Out:
#    SessionID      IpId           TimeStamp   Event       Action Product
# 0          0  100095PL  637145481360000000   Leave          NaN     NaN
# 1          1  100095PL  637228232800000000  Arrive          NaN     NaN
# 2          1  100095PL  637228233260000000     NaN  add_to_cart  p-9967
# 3          1  100095PL  637228243870000000     NaN        order     NaN
# 4          1  100095PL  637228244650000000   Leave          NaN     NaN

# %% [markdown]
# **From the documentation**: *TimeStamp – long integer value specifying the UTC date and time of the arrival of a request, coded as the number of 100-nanosecond intervals that have elapsed since 00:00:00 UTC on 1st January, 1 A.D.*

# %%
seconds = (datetime(1970,1,1)-datetime(1,1,1)).total_seconds()
ticks = seconds * 10**7
sessions['TimeStamp'] = pd.to_datetime((sessions['TimeStamp']-ticks)*100)
sessions.head()
# Out:
#    SessionID      IpId           TimeStamp   Event       Action Product
# 0          0  100095PL 2020-01-13 21:35:36   Leave          NaN     NaN
# 1          1  100095PL 2020-04-18 16:14:40  Arrive          NaN     NaN
# 2          1  100095PL 2020-04-18 16:15:26     NaN  add_to_cart  p-9967
# 3          1  100095PL 2020-04-18 16:33:07     NaN        order     NaN
# 4          1  100095PL 2020-04-18 16:34:25   Leave          NaN     NaN

# %%
sessions.sort_values('TimeStamp').head()
# Out:
#         SessionID  IpId           TimeStamp   Event       Action   Product
# 102414      36591   7PL 2019-11-30 23:00:09  Arrive          NaN       NaN
# 79103       27342  39PL 2019-11-30 23:02:05    Flit          NaN       NaN
# 100256      35771  74PL 2019-11-30 23:07:38  Arrive          NaN       NaN
# 103354      36946  81PL 2019-11-30 23:10:05  Arrive          NaN       NaN
# 100257      35771  74PL 2019-11-30 23:23:55     NaN  add_to_cart  c-35_313

# %%
pd.options.display.max_rows = 200
sessions.sort_values(['IpId','TimeStamp']).head(200)
# Out:
#      SessionID      IpId           TimeStamp   Event            Action  \
# 0            0  100095PL 2020-01-13 21:35:36   Leave               NaN
# 1            1  100095PL 2020-04-18 16:14:40  Arrive               NaN
# 2            1  100095PL 2020-04-18 16:15:26     NaN       add_to_cart
# 3            1  100095PL 2020-04-18 16:33:07     NaN             order
# 4            1  100095PL 2020-04-18 16:34:25   Leave               NaN
# 5            2    1000PL 2019-12-01 10:37:01    Flit               NaN
# 6            3    1000PL 2020-02-27 14:31:11  Arrive               NaN
# 7            3    1000PL 2020-02-27 14:31:22   Leave               NaN
# 8            4    1000PL 2020-03-13 13:14:06  Arrive               NaN
# 9            4    1000PL 2020-03-13 13:17:16   Leave               NaN
# 10           5    1000PL 2020-03-21 19:36:41    Flit               NaN
# 11           6    1000PL 2020-04-02 14:25:00  Arrive               NaN
# 12           6    1000PL 2020-04-02 14:25:25     NaN       add_to_cart
# 13           6    1000PL 2020-04-02 15:13:53   Leave               NaN
# 14           7    1000PL 2020-04-02 20:16:04  Arrive               NaN
# 15           7    1000PL 2020-04-02 20:16:08   Leave               NaN
# 16           8    1000PL 2020-04-03 10:18:20    Flit               NaN
# 17           9    1000PL 2020-04-12 07:30:30    Flit               NaN
# 18          10    1000PL 2020-04-12 10:12:35    Flit               NaN
# 19          11   10010PL 2019-12-03 11:28:53    Flit               NaN
# 20          12   10010PL 2020-01-04 22:46:07  Arrive               NaN
# 21          12   10010PL 2020-01-04 23:09:57     NaN       add_to_cart
# 22          12   10010PL 2020-01-04 23:18:54   Leave               NaN
# 23          13   10010PL 2020-01-27 09:15:17  Arrive               NaN
# 24          13   10010PL 2020-01-27 09:15:23   Leave               NaN
# 25          14   10010PL 2020-02-01 21:51:58  Arrive               NaN
# 26          14   10010PL 2020-02-01 21:52:05   Leave               NaN
# 27          15   10010PL 2020-02-03 18:05:07    Flit               NaN
# 28          16   10010PL 2020-02-09 16:07:28  Arrive               NaN
# 29          16   10010PL 2020-02-09 16:26:52   Leave               NaN
# 30          17   10010PL 2020-02-21 17:33:50  Arrive               NaN
# 31          17   10010PL 2020-02-21 17:33:58   Leave               NaN
# 32          18  100180PL 2020-01-13 22:44:22  Arrive               NaN
# 33          18  100180PL 2020-01-13 22:47:06   Leave               NaN
# 34          19  100180PL 2020-01-22 19:47:32  Arrive               NaN
# 35          19  100180PL 2020-01-22 19:52:22     NaN       add_to_cart
# 36          19  100180PL 2020-01-22 19:52:51     NaN       add_to_cart
# 37          19  100180PL 2020-01-22 19:53:13     NaN       add_to_cart
# 38          19  100180PL 2020-01-22 19:54:43     NaN       add_to_cart
# 39          19  100180PL 2020-01-22 20:07:39   Leave               NaN
# 40          20  100180PL 2020-01-23 16:15:16  Arrive               NaN
# 41          20  100180PL 2020-01-23 16:17:36     NaN       add_to_cart
# 42          20  100180PL 2020-01-23 16:18:28     NaN       add_to_cart
# 43          20  100180PL 2020-01-23 16:19:06     NaN       add_to_cart
# 44          20  100180PL 2020-01-23 16:22:41     NaN       add_to_cart
# 45          20  100180PL 2020-01-23 16:35:23     NaN       add_to_cart
# 46          20  100180PL 2020-01-23 17:30:06   Leave               NaN
# 47          21  100180PL 2020-01-23 19:38:40  Arrive               NaN
# 48          21  100180PL 2020-01-23 19:41:02     NaN       add_to_cart
# 49          21  100180PL 2020-01-23 19:45:30     NaN       add_to_cart
# 50          21  100180PL 2020-01-23 19:49:10     NaN       add_to_cart
# 51          21  100180PL 2020-01-23 19:53:44     NaN       add_to_cart
# 52          21  100180PL 2020-01-23 19:56:48     NaN       add_to_cart
# 53          21  100180PL 2020-01-23 20:00:34     NaN       add_to_cart
# 54          21  100180PL 2020-01-23 20:05:14     NaN      change_order
# 55          21  100180PL 2020-01-23 20:05:44     NaN             order
# 56          21  100180PL 2020-01-23 20:29:20   Leave               NaN
# 57          22  100180PL 2020-01-26 19:34:25  Arrive               NaN
# 58          22  100180PL 2020-01-26 20:03:12   Leave               NaN
# 59          23  100180PL 2020-01-26 21:30:04  Arrive               NaN
# 60          23  100180PL 2020-01-26 21:30:10   Leave               NaN
# 61          24  100180PL 2020-01-27 21:51:29  Arrive               NaN
# 62          24  100180PL 2020-01-27 21:51:34   Leave               NaN
# 63          25  100180PL 2020-01-27 23:24:43  Arrive               NaN
# 64          25  100180PL 2020-01-27 23:24:49   Leave               NaN
# 65          26  100180PL 2020-01-29 17:54:41  Arrive               NaN
# 66          26  100180PL 2020-01-29 17:59:15   Leave               NaN
# 67          27  100180PL 2020-01-31 23:14:37  Arrive               NaN
# 68          27  100180PL 2020-01-31 23:16:58   Leave               NaN
# 69          28  100180PL 2020-02-02 12:58:43  Arrive               NaN
# 70          28  100180PL 2020-02-02 13:21:58   Leave               NaN
# 71          29  100180PL 2020-02-02 17:18:12  Arrive               NaN
# 72          29  100180PL 2020-02-02 17:18:18   Leave               NaN
# 73          30  100180PL 2020-02-02 18:27:58  Arrive               NaN
# 74          30  100180PL 2020-02-02 18:30:28   Leave               NaN
# 75          31  100180PL 2020-02-02 19:47:36  Arrive               NaN
# 76          31  100180PL 2020-02-02 19:47:42   Leave               NaN
# 77          32  100180PL 2020-02-02 22:24:42  Arrive               NaN
# 78          32  100180PL 2020-02-02 22:48:26   Leave               NaN
# 79          33  100180PL 2020-02-05 21:05:37  Arrive               NaN
# 80          33  100180PL 2020-02-05 21:05:43   Leave               NaN
# 81          34  100180PL 2020-02-06 16:40:24  Arrive               NaN
# 82          34  100180PL 2020-02-06 16:41:46   Leave               NaN
# 83          35  100180PL 2020-02-07 19:55:38  Arrive               NaN
# 84          35  100180PL 2020-02-07 20:11:38   Leave               NaN
# 85          36  100180PL 2020-02-07 20:48:31  Arrive               NaN
# 86          36  100180PL 2020-02-07 21:02:49   Leave               NaN
# 87          37  100180PL 2020-02-07 22:09:18  Arrive               NaN
# 88          37  100180PL 2020-02-07 22:09:20   Leave               NaN
# 89          38  100180PL 2020-05-04 22:13:20  Arrive               NaN
# 90          38  100180PL 2020-05-04 22:13:47   Leave               NaN
# 91          39  100184PL 2020-01-13 22:45:00    Flit               NaN
# 92          40  100184PL 2020-02-21 09:30:38  Arrive               NaN
# 93          40  100184PL 2020-02-21 09:30:40   Leave               NaN
# 94          41  100184PL 2020-05-30 12:26:06  Arrive               NaN
# 95          41  100184PL 2020-05-30 12:33:09     NaN       add_to_cart
# 96          41  100184PL 2020-05-30 12:52:28     NaN       add_to_cart
# 97          41  100184PL 2020-05-30 12:54:58     NaN       add_to_cart
# 98          41  100184PL 2020-05-30 13:02:46   Leave               NaN
# 99          42  100186PL 2020-01-13 22:46:49  Arrive               NaN
# 100         42  100186PL 2020-01-13 22:46:56   Leave               NaN
# 101         43  100186PL 2020-02-10 18:25:33  Arrive               NaN
# 102         43  100186PL 2020-02-10 18:47:18     NaN       add_to_cart
# 103         43  100186PL 2020-02-10 18:47:42     NaN       add_to_cart
# 104         43  100186PL 2020-02-10 18:48:23     NaN       add_to_cart
# 105         43  100186PL 2020-02-10 18:48:34     NaN       add_to_cart
# 106         43  100186PL 2020-02-10 18:48:44     NaN       add_to_cart
# 107         43  100186PL 2020-02-10 18:48:53     NaN       add_to_cart
# 108         43  100186PL 2020-02-10 18:54:22     NaN       add_to_cart
# 109         43  100186PL 2020-02-10 18:54:30     NaN       add_to_cart
# 110         43  100186PL 2020-02-10 18:54:36     NaN       add_to_cart
# 111         43  100186PL 2020-02-10 18:55:08     NaN       add_to_cart
# 112         43  100186PL 2020-02-10 18:55:13     NaN       add_to_cart
# 113         43  100186PL 2020-02-10 18:55:13     NaN       add_to_cart
# 114         43  100186PL 2020-02-10 18:55:29     NaN       delete_cart
# 115         43  100186PL 2020-02-10 18:55:35   Leave               NaN
# 116         44  100186PL 2020-03-02 22:36:01    Flit               NaN
# 117         45  100186PL 2020-03-02 23:10:46    Flit               NaN
# 118         46  100186PL 2020-03-10 22:42:01  Arrive               NaN
# 119         46  100186PL 2020-03-10 22:48:49   Leave               NaN
# 120         47  100211PL 2020-01-13 23:18:26  Arrive               NaN
# 121         47  100211PL 2020-01-13 23:20:50     NaN       add_to_cart
# 122         47  100211PL 2020-01-13 23:21:35   Leave               NaN
# 123         48  100223PL 2020-01-13 23:41:16  Arrive               NaN
# 124         48  100223PL 2020-01-13 23:43:07     NaN       add_to_cart
# 125         48  100223PL 2020-01-13 23:58:02     NaN       add_to_cart
# 126         48  100223PL 2020-01-14 00:16:03   Leave               NaN
# 127         49  100288PL 2020-01-14 00:54:27  Arrive               NaN
# 128         49  100288PL 2020-01-14 01:04:42     NaN       add_to_cart
# 129         49  100288PL 2020-01-14 01:05:41     NaN       add_to_cart
# 130         49  100288PL 2020-01-14 01:05:54     NaN       add_to_cart
# 131         49  100288PL 2020-01-14 01:06:36     NaN       add_to_cart
# 132         49  100288PL 2020-01-14 01:06:48     NaN       add_to_cart
# 133         49  100288PL 2020-01-14 01:09:42     NaN       add_to_cart
# 134         49  100288PL 2020-01-14 01:09:56     NaN       add_to_cart
# 135         49  100288PL 2020-01-14 01:21:01     NaN             order
# 136         49  100288PL 2020-01-14 01:22:13   Leave               NaN
# 137         50   10031PL 2019-12-03 11:33:37  Arrive               NaN
# 138         50   10031PL 2019-12-03 11:33:44   Leave               NaN
# 139         51   10031PL 2019-12-12 18:07:50  Arrive               NaN
# 140         51   10031PL 2019-12-12 18:08:00   Leave               NaN
# 141         52   10031PL 2020-01-08 20:45:15  Arrive               NaN
# 142         52   10031PL 2020-01-08 20:45:30     NaN       add_to_cart
# 143         52   10031PL 2020-01-08 20:49:53   Leave               NaN
# 144         53   10031PL 2020-01-14 08:33:44  Arrive               NaN
# 145         53   10031PL 2020-01-14 08:34:20   Leave               NaN
# 146         54  100329PL 2020-01-14 01:14:07    Flit               NaN
# 147         55  100329PL 2020-04-16 07:22:00    Flit               NaN
# 148         56  100329PL 2020-05-21 18:09:18    Flit               NaN
# 149         57  100329PL 2020-05-23 08:42:52  Arrive               NaN
# 150         57  100329PL 2020-05-23 08:43:10     NaN       add_to_cart
# 151         57  100329PL 2020-05-23 08:45:01   Leave               NaN
# 152         58   10036PL 2019-12-03 11:34:33    Flit               NaN
# 153         59   10036PL 2020-02-05 18:28:28  Arrive               NaN
# 154         59   10036PL 2020-02-05 18:30:52     NaN       add_to_cart
# 155         59   10036PL 2020-02-05 18:45:13   Leave               NaN
# 156         60   10036PL 2020-03-09 16:09:51  Arrive               NaN
# 157         60   10036PL 2020-03-09 16:11:47   Leave               NaN
# 158         61   10036PL 2020-03-09 17:53:45  Arrive               NaN
# 159         61   10036PL 2020-03-09 17:53:45   Leave               NaN
# 160         62   10036PL 2020-04-07 13:53:18  Arrive               NaN
# 161         62   10036PL 2020-04-07 13:55:34   Leave               NaN
# 162         63   10036PL 2020-04-11 19:44:41    Flit               NaN
# 163         64  100482PL 2020-01-14 02:47:34  Arrive               NaN
# 164         64  100482PL 2020-01-14 02:52:24     NaN       add_to_cart
# 165         64  100482PL 2020-01-14 02:57:15     NaN       add_to_cart
# 166         64  100482PL 2020-01-14 03:12:52   Leave               NaN
# 167         65   10049PL 2019-12-03 11:38:02  Arrive               NaN
# 168         65   10049PL 2019-12-03 11:42:36     NaN       add_to_cart
# 169         65   10049PL 2019-12-03 11:45:14   Leave               NaN
# 170         66    1005PL 2019-12-01 10:38:38  Arrive               NaN
# 171         66    1005PL 2019-12-01 10:41:18     NaN       add_to_cart
# 172         66    1005PL 2019-12-01 10:42:35     NaN       add_to_cart
# 173         66    1005PL 2019-12-01 10:42:51     NaN       add_to_cart
# 174         66    1005PL 2019-12-01 10:44:46     NaN       add_to_cart
# 175         66    1005PL 2019-12-01 10:51:31     NaN       add_to_cart
# 176         66    1005PL 2019-12-01 10:59:23     NaN       add_to_cart
# 177         66    1005PL 2019-12-01 11:01:19     NaN  remove_from_cart
# 178         66    1005PL 2019-12-01 11:01:45     NaN  remove_from_cart
# 179         66    1005PL 2019-12-01 11:02:27     NaN       add_to_cart
# 180         66    1005PL 2019-12-01 11:03:02     NaN       add_to_cart
# 181         66    1005PL 2019-12-01 11:03:18     NaN       add_to_cart
# 182         66    1005PL 2019-12-01 11:03:27     NaN       add_to_cart
# 183         66    1005PL 2019-12-01 11:09:39     NaN             order
# 184         66    1005PL 2019-12-01 11:09:45   Leave               NaN
# 185         67    1005PL 2020-01-27 00:35:16  Arrive               NaN
# 186         67    1005PL 2020-01-27 00:35:16   Leave               NaN
# 187         68    1005PL 2020-02-04 16:30:34    Flit               NaN
# 188         69    1005PL 2020-02-12 14:17:56    Flit               NaN
# 189         70    1005PL 2020-03-18 13:23:09    Flit               NaN
# 190         71    1005PL 2020-04-26 07:34:50  Arrive               NaN
# 191         71    1005PL 2020-04-26 07:37:19     NaN       add_to_cart
# 192         71    1005PL 2020-04-26 07:37:31     NaN       add_to_cart
# 193         71    1005PL 2020-04-26 07:37:48     NaN       add_to_cart
# 194         71    1005PL 2020-04-26 07:38:07     NaN       add_to_cart
# 195         71    1005PL 2020-04-26 07:38:22     NaN       add_to_cart
# 196         71    1005PL 2020-04-26 07:38:30     NaN       add_to_cart
# 197         71    1005PL 2020-04-26 07:42:04     NaN       add_to_cart
# 198         71    1005PL 2020-04-26 07:48:36   Leave               NaN
# 199         72    1005PL 2020-05-22 07:55:15  Arrive               NaN
#
#            Product
# 0              NaN
# 1              NaN
# 2           p-9967
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12         p-10519
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21          p-7414
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35          p-6769
# 36          p-6769
# 37          p-4466
# 38          p-8068
# 39             NaN
# 40             NaN
# 41        c-34_307
# 42        c-34_356
# 43        c-34_356
# 44        c-34_307
# 45        c-34_110
# 46             NaN
# 47             NaN
# 48        c-34_356
# 49        c-34_118
# 50        c-34_356
# 51        c-34_113
# 52        c-34_118
# 53          p-1775
# 54             NaN
# 55             NaN
# 56             NaN
# 57             NaN
# 58             NaN
# 59             NaN
# 60             NaN
# 61             NaN
# 62             NaN
# 63             NaN
# 64             NaN
# 65             NaN
# 66             NaN
# 67             NaN
# 68             NaN
# 69             NaN
# 70             NaN
# 71             NaN
# 72             NaN
# 73             NaN
# 74             NaN
# 75             NaN
# 76             NaN
# 77             NaN
# 78             NaN
# 79             NaN
# 80             NaN
# 81             NaN
# 82             NaN
# 83             NaN
# 84             NaN
# 85             NaN
# 86             NaN
# 87             NaN
# 88             NaN
# 89             NaN
# 90             NaN
# 91             NaN
# 92             NaN
# 93             NaN
# 94             NaN
# 95         p-10618
# 96          p-7980
# 97          p-9829
# 98             NaN
# 99             NaN
# 100            NaN
# 101            NaN
# 102        c-39_40
# 103        c-39_40
# 104        c-39_41
# 105        c-39_41
# 106        c-39_41
# 107        c-39_41
# 108        c-39_42
# 109        c-39_42
# 110        c-39_42
# 111        c-39_42
# 112        c-39_42
# 113        c-39_42
# 114            NaN
# 115            NaN
# 116            NaN
# 117            NaN
# 118            NaN
# 119            NaN
# 120            NaN
# 121         p-5412
# 122            NaN
# 123            NaN
# 124         p-8577
# 125         p-9324
# 126            NaN
# 127            NaN
# 128           c-38
# 129           c-38
# 130           c-38
# 131           c-38
# 132           c-38
# 133           c-38
# 134           c-38
# 135            NaN
# 136            NaN
# 137            NaN
# 138            NaN
# 139            NaN
# 140            NaN
# 141            NaN
# 142         p-7933
# 143            NaN
# 144            NaN
# 145            NaN
# 146            NaN
# 147            NaN
# 148            NaN
# 149            NaN
# 150         p-9967
# 151            NaN
# 152            NaN
# 153            NaN
# 154           c-30
# 155            NaN
# 156            NaN
# 157            NaN
# 158            NaN
# 159            NaN
# 160            NaN
# 161            NaN
# 162            NaN
# 163            NaN
# 164         p-3937
# 165         p-8593
# 166            NaN
# 167            NaN
# 168         p-5127
# 169            NaN
# 170            NaN
# 171         p-8699
# 172         p-9693
# 173  c-317_322_327
# 174         p-8211
# 175         p-6608
# 176         p-7948
# 177            NaN
# 178            NaN
# 179  c-317_322_327
# 180  c-317_322_327
# 181  c-317_322_327
# 182  c-317_322_327
# 183            NaN
# 184            NaN
# 185            NaN
# 186            NaN
# 187            NaN
# 188            NaN
# 189            NaN
# 190            NaN
# 191  c-317_322_327
# 192  c-317_322_327
# 193  c-317_322_327
# 194  c-317_322_327
# 195  c-317_322_327
# 196  c-317_322_327
# 197       c-24_203
# 198            NaN
# 199            NaN

# %%
print(sessions.shape)
print(sessions['SessionID'].max())
# Out:
# (112256, 6)
# 40297

# %%
sessions_1d = sessions[sessions['TimeStamp'].between(datetime(2019,12,10,23,0,0),datetime(2019,12,11,22,59,59))]
sessions_1d.head()
# Out:
#       SessionID     IpId           TimeStamp   Event       Action Product
# 654         207  10201PL 2019-12-11 13:50:36  Arrive          NaN     NaN
# 655         207  10201PL 2019-12-11 13:50:53     NaN  add_to_cart  p-9623
# 656         207  10201PL 2019-12-11 14:01:02   Leave          NaN     NaN
# 1178        385  10318PL 2019-12-11 12:20:24  Arrive          NaN     NaN
# 1179        385  10318PL 2019-12-11 12:22:45   Leave          NaN     NaN

# %%
sessions_1d.to_csv('1dfromsqlite.csv')
